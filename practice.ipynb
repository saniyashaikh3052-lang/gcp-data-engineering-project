# %%
import requests
import json
API_KEY = "2203c865d6a4d386b4ffd5dd50f3b021"
url = "https://api.themoviedb.org/3/trending/all/day?api_key=2203c865d6a4d386b4ffd5dd50f3b021"
params = {"api_key" : API_KEY , "language" : "en-US" , "page" : 1}
response = requests.get(url, params = params)
response.status_code 

data = json.dumps(response.json(),indent = 4)
print(data) 
print(response.url)
# Out:
# {
#     "page": 1,
#     "results": [
#         {
#             "adult": false,
#             "backdrop_path": "/8Tfys3mDZVp4tNoH2ktm06a0Tau.jpg",
#             "id": 687163,
#             "title": "Project Hail Mary",
#             "original_title": "Project Hail Mary",
#             "overview": "Science teacher Ryland Grace wakes up on a spaceship light years from home with no recollection of who he is or how he got there. As his memory returns, he begins to uncover his mission: solve the riddle of the mysterious substance causing the sun to die out. He must call on his scientific knowledge and unorthodox ideas to save everything on Earth from extinction.",
#             "poster_path": "/yihdXomYb5kTeSivtFndMy5iDmf.jpg",
#             "media_type": "movie",
#             "original_language": "en",
#             "genre_ids": [
#                 878,
#                 12
#             ],
#             "popularity": 369.2965,
#             "release_date": "2026-03-15",
#             "softcore": false,
#             "video": false,
#             "vote_average": 8.4,
#             "vote_count": 2613
#         },
#         {
#             "adult": false,
#             "backdrop_path": "/qO55CD8tgVL1T4WKn6zYFFiD6lL.jpg",
#             "id": 1439930,
#             "title": "A Marvel Television Special Presentation - The Punisher: One Last Kill",
#             "original_title": "A Marvel Television Special Presentation - The Punisher: One Last Kill",
#             "overview": "As Frank Castle searches for meaning beyond revenge, an unexpected force pulls him back into the fight.",
#             "poster_path": "/wjcPbV53ovhlogVFYdmkTDBooqg.jpg",
#             "media_type": "movie",
#             "original_language": "en",
#             "genre_ids": [
#                 28,
#                 80,
#                 18
#             ],
#             "popularity": 34.1264,
#             "release_date": "2026-05-12",
#             "softcore": false,
#             "video": false,
#             "vote_average": 8.9,
#             "vote_count": 8
#         },
#         {
#             "adult": false,
#             "backdrop_path": "/nLyXXIDMpDHvUgxchezxuhoJ4Ej.jpg",
#             "id": 235930,
#             "name": "Devil May Cry",
#             "original_name": "Devil May Cry",
#             "overview": "In this epic battle of good vs. evil, the lines are blurry as hell. But a devilishly handsome demon hunter could be the world's best hope for salvation.",
#             "poster_path": "/mX9tqfpjqwreONJHhap7SnSSowe.jpg",
#             "media_type": "tv",
#             "original_language": "en",
#             "genre_ids": [
#                 16,
#                 10759,
#                 10765
#             ],
#             "popularity": 59.4114,
#             "first_air_date": "2025-04-03",
#             "softcore": false,
#             "vote_average": 7.998,
#             "vote_count": 322,
#             "origin_country": [
#                 "US"
#             ]
#         },
#         {
#             "adult": false,
#             "backdrop_path": "/bq28ajZaoMyzEIm6REelqyqtEDZ.jpg",
#             "id": 76479,
#             "name": "The Boys",
#             "original_name": "The Boys",
#             "overview": "A group of vigilantes known informally as \u201cThe Boys\u201d set out to take down corrupt superheroes with no more than blue-collar grit and a willingness to fight dirty.",
#             "poster_path": "/in1R2dDc421JxsoRWaIIAqVI2KE.jpg",
#             "media_type": "tv",
#             "original_language": "en",
#             "genre_ids": [
#                 10765,
#                 10759
#             ],
#             "popularity": 569.2258,
#             "first_air_date": "2019-07-25",
#             "softcore": false,
#             "vote_average": 8.5,
#             "vote_count": 12255,
#             "origin_country": [
#                 "US"
#             ]
#         },
#         {
#             "adult": false,
#             "backdrop_path": "/r7AKQ0OB69JOPskeTWL3U206ehY.jpg",
#             "id": 855435,
#             "title": "Faces of Death",
#             "original_title": "Faces of Death",
#             "overview": "A moderator on an internet video-sharing platform stumbles across a potential snuff film ring hidden in the depths of the site's content.",
#             "poster_path": "/vPVY3S57lEooBLJCg6KGdMHkUxm.jpg",
#             "media_type": "movie",
#             "original_language": "en",
#             "genre_ids": [
#                 27
#             ],
#             "popularity": 34.925,
#             "release_date": "2026-04-10",
#             "softcore": false,
#             "video": false,
#             "vote_average": 6.5,
#             "vote_count": 13
#         },
#         {
#             "adult": false,
#             "backdrop_path": "/qjv21Iu0nHQ0crJpy6KKiW8LX1Y.jpg",
#             "id": 931285,
#             "title": "Mortal Kombat II",
#             "original_title": "Mortal Kombat II",
#             "overview": "The fan favorite champions\u2014now joined by Johnny Cage himself\u2014are pitted against one another in the ultimate, no-holds barred, gory battle to defeat the dark rule of Shao Kahn that threatens the very existence of the Earthrealm and its defenders.",
#             "poster_path": "/lIsMeDbwntNXSUVHmWMMRXEZOVc.jpg",
#             "media_type": "movie",
#             "original_language": "en",
#             "genre_ids": [
#                 28,
#                 14,
#                 12
#             ],
#             "popularity": 223.6578,
#             "release_date": "2026-05-06",
#             "softcore": false,
#             "video": false,
#             "vote_average": 7.118,
#             "vote_count": 131
#         },
#         {
#             "adult": false,
#             "backdrop_path": "/auyEi4Xho43HFvVQnd42LzqBdiV.jpg",
#             "id": 124364,
#             "name": "FROM",
#             "original_name": "FROM",
#             "overview": "Unravel the mystery of a nightmarish town in middle America that traps all those who enter. As the unwilling residents fight to keep a sense of normalcy and search for a way out, they must also survive the threats of the surrounding forest \u2013 including the terrifying creatures that come out when the sun goes down.",
#             "poster_path": "/pRtJagIxpfODzzb0T0NAvZSzErC.jpg",
#             "media_type": "tv",
#             "original_language": "en",
#             "genre_ids": [
#                 9648,
#                 18,
#                 10765
#             ],
#             "popularity": 612.0636,
#             "first_air_date": "2022-02-20",
#             "softcore": false,
#             "vote_average": 8.318,
#             "vote_count": 3066,
#             "origin_country": [
#                 "US"
#             ]
#         },
#         {
#             "adult": false,
#             "backdrop_path": "/mez2Z3WqlPKNXpi7mWoiiE5guE9.jpg",
#             "id": 85552,
#             "name": "Euphoria",
#             "original_name": "Euphoria",
#             "overview": "A group of high school students navigate love and friendships in a world of drugs, sex, trauma, and social media.",
#             "poster_path": "/aJrG7OkoTMPWG5c8opz8a93AZPY.jpg",
#             "media_type": "tv",
#             "original_language": "en",
#             "genre_ids": [
#                 18
#             ],
#             "popularity": 273.882,
#             "first_air_date": "2019-06-16",
#             "softcore": false,
#             "vote_average": 8.284,
#             "vote_count": 10584,
#             "origin_country": [
#                 "US"
#             ]
#         },
#         {
#             "adult": false,
#             "backdrop_path": "/xBT0oNq6rsTFv4SxG5uGRIEOrq6.jpg",
#             "id": 936075,
#             "title": "Michael",
#             "original_title": "Michael",
#             "overview": "The story of Michael Jackson, one of the most influential artists the world has ever known, and his life beyond the music. His journey from the discovery of his extraordinary talent as the lead of the Jackson Five, to the visionary artist whose creative ambition fueled a relentless pursuit to become the biggest entertainer in the world, highlighting both his life off-stage and some of the most iconic performances from his early solo career.",
#             "poster_path": "/3Qud19bBUrrJAzy0Ilm8gRJlJXP.jpg",
#             "media_type": "movie",
#             "original_language": "en",
#             "genre_ids": [
#                 10402,
#                 18
#             ],
#             "popularity": 159.5523,
#             "release_date": "2026-04-22",
#             "softcore": false,
#             "video": false,
#             "vote_average": 7.6,
#             "vote_count": 660
#         },
#         {
#             "adult": false,
#             "backdrop_path": "/zMwhWailP1WY7sb6AoE6b8ugoy.jpg",
#             "id": 1007757,
#             "title": "Swapped",
#             "original_title": "Swapped",
#             "overview": "A small woodland creature and a majestic bird, two natural sworn enemies of the Valley, magically trade places and set off on an adventure of a lifetime to switch back. Their journey soon uncovers a greater threat\u2014one that could endanger not only their species, but the entire valley they call home.",
#             "poster_path": "/tHhxWxge06goXU6ZQH1hj7vK8Hd.jpg",
#             "media_type": "movie",
#             "original_language": "en",
#             "genre_ids": [
#                 16,
#                 10751,
#                 12,
#                 18,
#                 14
#             ],
#             "popularity": 439.3294,
#             "release_date": "2026-05-01",
#             "softcore": false,
#             "video": false,
#             "vote_average": 8.957,
#             "vote_count": 679
#         },
#         {
#             "adult": false,
#             "backdrop_path": "/bVGHSe47W6oCQL1Q88pvRAet51A.jpg",
#             "id": 1330021,
#             "title": "Remarkably Bright Creatures",
#             "original_title": "Remarkably Bright Creatures",
#             "overview": "Through unlikely bonds formed during night shifts at a local aquarium, Tova, an elderly widow, learns of a life-changing discovery that may bring her joy and wonder once again.",
#             "poster_path": "/9HcEqn3D4J6b2Z0jK54id9nA0fr.jpg",
#             "media_type": "movie",
#             "original_language": "en",
#             "genre_ids": [
#                 18,
#                 9648
#             ],
#             "popularity": 141.8722,
#             "release_date": "2026-05-07",
#             "softcore": false,
#             "video": false,
#             "vote_average": 8.4,
#             "vote_count": 140
#         },
#         {
#             "adult": false,
#             "backdrop_path": "/y3fQa7pytlysovXzovpXc1OQlTW.jpg",
#             "id": 1314481,
#             "title": "The Devil Wears Prada 2",
#             "original_title": "The Devil Wears Prada 2",
#             "overview": "Andy Sachs returns to Runway as Miranda Priestly navigates a new media landscape and Runway's position within. The duo reconnect with former assistant Emily Charlton, now the head of a luxury brand that possesses funding which could ensure Runway's survival.",
#             "poster_path": "/xTI42pmsP5EDnvsNJPEDubwWBQO.jpg",
#             "media_type": "movie",
#             "original_language": "en",
#             "genre_ids": [
#                 35,
#                 18
#             ],
#             "popularity": 106.6627,
#             "release_date": "2026-04-29",
#             "softcore": false,
#             "video": false,
#             "vote_average": 6.755,
#             "vote_count": 462
#         },
#         {
#             "adult": false,
#             "backdrop_path": "/9Z2uDYXqJrlmePznQQJhL6d92Rq.jpg",
#             "id": 1226863,
#             "title": "The Super Mario Galaxy Movie",
#             "original_title": "The Super Mario Galaxy Movie",
#             "overview": "Having thwarted Bowser's previous plot to marry Princess Peach, Mario and Luigi now face a fresh threat in Bowser Jr., who is determined to liberate his father from captivity and restore the family legacy. Alongside companions new and old, the brothers travel across the stars to stop the young heir's crusade.",
#             "poster_path": "/eJGWx219ZcEMVQJhAgMiqo8tYY.jpg",
#             "media_type": "movie",
#             "original_language": "en",
#             "genre_ids": [
#                 10751,
#                 35,
#                 12,
#                 14,
#                 16
#             ],
#             "popularity": 385.0295,
#             "release_date": "2026-04-01",
#             "softcore": false,
#             "video": false,
#             "vote_average": 6.699,
#             "vote_count": 818
#         },
#         {
#             "adult": false,
#             "backdrop_path": "/mWRjVb2Lj9pjOlNcDP7lNvrvSo8.jpg",
#             "id": 1400357,
#             "title": "The Christophers",
#             "original_title": "The Christophers",
#             "overview": "The estranged children of a once-famous artist hire a forger to complete his unfinished works so they can be \"discovered\" and sold after his death.",
#             "poster_path": "/s6oUrGMNl8hVh7fn0O8oF2rHwrM.jpg",
#             "media_type": "movie",
#             "original_language": "en",
#             "genre_ids": [
#                 80,
#                 35
#             ],
#             "popularity": 16.316,
#             "release_date": "2026-04-10",
#             "softcore": false,
#             "video": false,
#             "vote_average": 6.8,
#             "vote_count": 3
#         },
#         {
#             "adult": false,
#             "backdrop_path": "/rZfmzpixLKLR3Hg2u0WgC7XLFl8.jpg",
#             "id": 1339713,
#             "title": "Obsession",
#             "original_title": "Obsession",
#             "overview": "After breaking the mysterious \"One Wish Willow\" to win his crush's heart, a hopeless romantic finds himself getting exactly what he asked for but soon discovers that some desires come at a dark, sinister price.",
#             "poster_path": "/40I66L7QKguTFDPvcLcdiTbAD7I.jpg",
#             "media_type": "movie",
#             "original_language": "en",
#             "genre_ids": [
#                 27
#             ],
#             "popularity": 33.6232,
#             "release_date": "2026-04-16",
#             "softcore": false,
#             "video": false,
#             "vote_average": 6.893,
#             "vote_count": 14
#         },
#         {
#             "adult": false,
#             "backdrop_path": "/43Tu4TnFO57R6eK6XUBFGJrazrZ.jpg",
#             "id": 256695,
#             "name": "Regular Show: The Lost Tapes",
#             "original_name": "Regular Show: The Lost Tapes",
#             "overview": "Familiar duo Mordecai and Rigby navigate mundane park jobs that inevitably spiral into surreal, chaotic disasters.",
#             "poster_path": "/jqY3dj70ffSqKpM8XVUEToOEeLG.jpg",
#             "media_type": "tv",
#             "original_language": "en",
#             "genre_ids": [
#                 16,
#                 35,
#                 10759,
#                 10765
#             ],
#             "popularity": 35.9478,
#             "first_air_date": "2026-05-11",
#             "softcore": false,
#             "vote_average": 9.667,
#             "vote_count": 3,
#             "origin_country": [
#                 "US"
#             ]
#         },
#         {
#             "adult": false,
#             "backdrop_path": "/cSjhFNOmjYSH5n0JrirtvD95wVS.jpg",
#             "id": 1620034,
#             "title": "Marty, Life Is Short",
#             "original_title": "Marty, Life Is Short",
#             "overview": "Martin Short looks back on a life fueled by joy in this documentary with classic clips, fresh interviews and star-studded, never-before-seen home movies.",
#             "poster_path": "/vWgqvwe2MlDYXaXQ81XdgcJspMS.jpg",
#             "media_type": "movie",
#             "original_language": "en",
#             "genre_ids": [
#                 99
#             ],
#             "popularity": 10.138,
#             "release_date": "2026-05-11",
#             "softcore": false,
#             "video": false,
#             "vote_average": 0.0,
#             "vote_count": 0
#         },
#         {
#             "adult": false,
#             "backdrop_path": "/2TWIlmhE06ghspeQLEX1VmnEBiE.jpg",
#             "id": 1455079,
#             "title": "You, Me & Tuscany",
#             "original_title": "You, Me & Tuscany",
#             "overview": "When a woman crashes at an empty Italian villa, posing as the owner's fianc\u00e9e, she discovers an unexpected romance that could transform her life.",
#             "poster_path": "/mJS0IF7Af3WpPRhSTDT6rGpiLzw.jpg",
#             "media_type": "movie",
#             "original_language": "en",
#             "genre_ids": [
#                 10749,
#                 35
#             ],
#             "popularity": 9.6961,
#             "release_date": "2026-04-09",
#             "softcore": false,
#             "video": false,
#             "vote_average": 4.9,
#             "vote_count": 14
#         },
#         {
#             "adult": false,
#             "backdrop_path": "/qrTAc0ZtQ859Qu5O8cixJzNJpQs.jpg",
#             "id": 202555,
#             "name": "Daredevil: Born Again",
#             "original_name": "Daredevil: Born Again",
#             "overview": "Matt Murdock, a blind lawyer with heightened abilities, is fighting for justice through his bustling law firm, while former mob boss Wilson Fisk pursues his own political endeavors in New York. When their past identities begin to emerge, both men find themselves on an inevitable collision course.",
#             "poster_path": "/xDUoAsU8lQHOOoRkFiBuarmACDN.jpg",
#             "media_type": "tv",
#             "original_language": "en",
#             "genre_ids": [
#                 18,
#                 10759,
#                 80
#             ],
#             "popularity": 112.5471,
#             "first_air_date": "2025-03-04",
#             "softcore": false,
#             "vote_average": 8.124,
#             "vote_count": 870,
#             "origin_country": [
#                 "US"
#             ]
#         },
#         {
#             "adult": false,
#             "backdrop_path": "/9lQZ18CYk5n3YNbOfmSjkiBrfrk.jpg",
#             "id": 295509,
#             "name": "The Legend of Kitchen Soldier",
#             "original_name": "\ucde8\uc0ac\ubcd1 \uc804\uc124\uc774 \ub418\ub2e4",
#             "overview": "A military cook, Kang Seong-jae, accepts a quest to become legendary. With quirky comrades\u2014a foul-mouthed sergeant, a strict lieutenant, and a clueless senior cook\u2014he brings chaos and heartwarming humor to the camp.",
#             "poster_path": "/zRQylnX3LydtVfBYS8r5qD1bEhz.jpg",
#             "media_type": "tv",
#             "original_language": "ko",
#             "genre_ids": [
#                 10765,
#                 35,
#                 18
#             ],
#             "popularity": 49.6535,
#             "first_air_date": "2026-05-11",
#             "softcore": false,
#             "vote_average": 10.0,
#             "vote_count": 1,
#             "origin_country": [
#                 "KR"
#             ]
#         }
#     ],
#     "total_pages": 500,
#     "total_results": 10000
# }
# https://api.themoviedb.org/3/trending/all/day?api_key=2203c865d6a4d386b4ffd5dd50f3b021&api_key=2203c865d6a4d386b4ffd5dd50f3b021&language=en-US&page=1

# %%
# Out:
# Request failed , Error code :404
